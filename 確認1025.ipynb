# %% [markdown]
# index2 でうまくいくのか試験

# %%
import numpy as np
import generate_HNF
import spglib
from copy import deepcopy
import permutation
import generate_superlattice

rutile = ([(4, 0, 0),

           (0, 4, 0),

           (0, 0, 3)],

          [(0, 0, 0),

           (0.5, 0.5, 0.5),

           (0.3, 0.3, 0.0),

           (0.7, 0.7, 0.0),

           (0.2, 0.8, 0.5),

           (0.8, 0.2, 0.5)],

          [14, 14, 8, 8, 8, 8])
o_sublattice = ([(4, 0, 0),

                 (0, 4, 0),

                 (0, 0, 3)],

                [(0.3, 0.3, 0.0),

                 (0.7, 0.7, 0.0),

                 (0.2, 0.8, 0.5),

                 (0.8, 0.2, 0.5)],

                [8, 8, 8, 8])
parent_sym = spglib.get_symmetry(rutile)
HNF_list = generate_HNF.generate_all_superlattices(2)
reduced_HNF = generate_HNF.reduce_HNF_list_by_parent_lattice_symmetry(
    HNF_list, parent_sym["rotations"])

# %%
parent_lattice = generate_superlattice.get_superlattice(rutile, reduced_HNF[4], 2)
o_sublattice = generate_superlattice.get_o_superlattice(rutile, reduced_HNF[4], 2)
o_sublattice
# Out:
# ([[4, 4, 0], [0, 8, 0], [0, 0, 3]],
#  [[0.3, 0.0, 0.0],
#   [0.7, 0.0, 0.0],
#   [0.2, 0.3, 0.5],
#   [0.3, 0.5, 0.0],
#   [0.7, 0.5, 0.0],
#   [0.2, 0.8, 0.5],
#   [0.8, 0.2, 0.5],
#   [0.8, 0.7, 0.5]],
#  [8, 8, 8, 8, 8, 8, 8, 8])

# %%
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer

# %%
for jack in range(5):
    print("今はi = ", jack)
    a = list()
    parent_lattice = generate_superlattice.get_superlattice(rutile, reduced_HNF[jack], 2)
    o_sublattice = generate_superlattice.get_o_superlattice(rutile, reduced_HNF[jack], 2)
    parent_lattice_jun = permutation.generate_per(parent_lattice, o_sublattice)
    for ken in range(8):
        can = permutation.make_candidate(o_sublattice, ken)
        auncko = permutation.unique(parent_lattice_jun, can)
        a.extend(auncko)
    print(a)
# Out:
# 今はi =  0
# ['00000001', '01010000', '00000011', '00010001', '00010010', '00000101', '00011000', '01010100', '00010101', '01110000', '00010110', '01010001', '01010010', '00000111', '00011100', '00011001', '00010011', '01110010', '00011110', '00010111', '01111000', '01110100', '00110011', '00011101', '00001111', '01010110', '00011011', '11110000', '01011100', '01010101', '01010011', '01011010', '01111100', '01111010', '00011111', '11110001', '00110111', '01011110', '01110110', '01010111', '01011101', '01011011', '01110011', '01110111', '01111011', '01011111', '01111110', '11110011', '11110101', '00111111', '01111111', '11110111']
# 今はi =  1
# ['00000001', '00000011', '00001010', '00000110', '00010001', '00000101', '00100001', '00011000', '00001011', '00101001', '00010101', '00100011', '00000111', '00011010', '00011100', '00101010', '00011001', '00010011', '00101110', '00111001', '00011110', '00010111', '00110101', '00011101', '00110011', '00001111', '00101011', '01010110', '00011011', '00111100', '00111010', '01010101', '00100111', '01100110', '01011010', '00101111', '00111011', '00011111', '00111101', '00110111', '01110101', '01010111', '01101011', '01100111', '01011011', '00111110', '01110111', '01111011', '01011111', '01111110', '10101111', '00111111', '01101111', '01111111']
# 今はi =  2
# ['00000010', '00000001', '00000011', '00001010', '00000110', '00001001', '00010001', '00000101', '00001011', '00001101', '00001110', '00010101', '01100010', '00000111', '00011001', '00010011', '00011110', '00010111', '00110101', '01101010', '00011101', '00001111', '00101011', '00011011', '00101101', '01101100', '11100001', '01100011', '01100101', '01100110', '00101111', '01101101', '01111010', '00111011', '00011111', '00111101', '01101110', '00110111', '01110101', '11100011', '01100111', '01110111', '11100111', '01111110', '11101011', '00111111', '01111101', '01101111', '01111111', '11101111']
# 今はi =  3
# ['00000010', '00000001', '00000011', '00001010', '01100000', '00000110', '00001100', '00010001', '10000001', '00000101', '00011000', '00001011', '00001101', '00100101', '00100110', '00001110', '00110100', '00111000', '00010101', '00100011', '00000111', '00011010', '00101010', '00011001', '00010011', '00111001', '00110101', '00011101', '00001111', '00011011', '00111010', '01010101', '00011110', '00111100', '00110110', '00101110', '00010111', '01101010', '00110011', '10000111', '11100001', '00100111', '01001011', '01100110', '00101011', '01000111', '10001011', '00101111', '00111011', '00011111', '00111101', '01101110', '10011011', '00110111', '01001111', '01110101', '01010111', '01101011', '01100111', '10001111', '10100111', '01011011', '00111110', '01110111', '10110111', '01111011', '11100111', '01011111', '01111110', '10101111', '00111111', '10011111', '01101111', '01111111', '10111111']
# 今はi =  4
# ['00000010', '00000001', '01000010', '00000011', '00001010', '00000110', '00001001', '01000001', '00010001', '00000101', '00100001', '00011000', '00001011', '00001101', '00001110', '01001001', '00101001', '01000101', '00010101', '00100011', '01100001', '01100100', '01100010', '00000111', '00011010', '01000011', '11000001', '00011001', '00010011', '01110010', '00111001', '01101001', '00011101', '00001111', '00011011', '00101101', '01010101', '01100011', '01100101', '00011110', '01011001', '00010111', '01101010', '11000011', '11100001', '01001101', '00100111', '01001011', '01100110', '01110001', '00101011', '01000111', '11000101', '00101111', '01101101', '01111001', '11001011', '00111011', '00011111', '11000111', '01001111', '01110110', '01110101', '01010111', '11100011', '01101011', '01100111', '01011101', '01011011', '01110011', '01110111', '11001111', '01111011', '11100111', '01011111', '11101011', '00111111', '01111101', '01101111', '01111111', '11101111']

# %%
import numpy as np
import pymatgen
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from pymatgen.core import Lattice, Structure
from pymatgen.core.periodic_table import DummySpecie
from pymatgen.io.cif import CifWriter
sga = SpacegroupAnalyzer(o_sublattice, symprec=1e-6, angle_tolerance=1e-2)
struct = sga.get_primitive_standard_structure()
struct
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-51eac84be1ce> in <module>
#       5 from pymatgen.core.periodic_table import DummySpecie
#       6 from pymatgen.io.cif import CifWriter
# ----> 7 sga = SpacegroupAnalyzer(o_sublattice, symprec=1e-6, angle_tolerance=1e-2)
#       8 struct = sga.get_primitive_standard_structure()
#       9 struct
#
# ~/.pyenv/versions/miniconda3-4.3.21/envs/py35a/lib/python3.5/site-packages/pymatgen/symmetry/analyzer.py in __init__(self, structure, symprec, angle_tolerance)
#      67         self._angle_tol = angle_tolerance
#      68         self._structure = structure
# ---> 69         latt = structure.lattice.matrix
#      70         positions = structure.frac_coords
#      71         unique_species = []
#
# AttributeError: 'tuple' object has no attribute 'lattice'

# %%
import os


from pymatgen.io.cif import CifWriter
from pymatgen.io.cif import CifParser
from pymatgen.core import Specie, DummySpecie
from pymatgen.core import Lattice, Structure


def write_cif(filename, struct, refine_cell=False, resize_volume=False):

    cw = CifWriter(struct)

    cw.write_file(filename)

# %%
latt = Lattice(o_sublattice[0])
latt
# Out:
# Lattice
#     abc : 5.656854249492381 8.0 3.0
#  angles : 90.0 90.0 45.00000000000001
#  volume : 96.0
#       A : 4.0 4.0 0.0
#       B : 0.0 8.0 0.0
#       C : 0.0 0.0 3.0

# %%
[DummySpecie('X')]
# Out:
# [DummySpecie X0+]

# %%
struct = Structure(o_sublattice[0],o_sublattice[2], o_sublattice[1])
struct.to(filename="tin.cif")

# %%
ls
# Out:
# 1025_index3-checkpoint.ipynb  __pycache__/              permutation.py
# README.md                     generate_HNF.py           tin.cif
# __init__.py                   generate_superlattice.py  確認-checkpoint.ipynb

# %%
def get_structure(filename):

    cp = CifParser(filename)

    structure = cp.get_structures(primitive=True)[0]

    return structure

# %%
rutile = get_structure('/home/asa/dsenum/dsenum/examples/TiO2_mp-2657_conventional_standard.cif')

# %%
rutile
# Out:
# Structure Summary
# Lattice
#     abc : 2.96920288 4.65327231 4.65327231
#  angles : 90.0 90.0 90.0
#  volume : 64.29198128323142
#       A : -0.0 -0.0 2.96920288
#       B : 4.65327231 -0.0 2.849307520001255e-16
#       C : 7.483032596824123e-16 4.65327231 2.849307520001255e-16
# PeriodicSite: Ti (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
# PeriodicSite: Ti (2.3266, 2.3266, 1.4846) [0.5000, 0.5000, 0.5000]
# PeriodicSite: O (0.9093, 3.7439, 1.4846) [0.5000, 0.1954, 0.8046]
# PeriodicSite: O (3.7439, 0.9093, 1.4846) [0.5000, 0.8046, 0.1954]
# PeriodicSite: O (3.2360, 3.2360, 2.9692) [1.0000, 0.6954, 0.6954]
# PeriodicSite: O (1.4173, 1.4173, 0.0000) [0.0000, 0.3046, 0.3046]

# %%
rutile.to(fmt="poscar")
rutile.to(filename="POSCAR")

# %%
ls
# Out:
# 916仕切り直し.ipynb       matome922.ipynb        taishousousa919.ipynb
# 920.ipynb                 O_sublattice919.ipynb  unko.py
# generate_HNF.py           permutation.py         Untitled.ipynb
# generate_superlattice.py  POSCAR                 utils.py
# hello_world.py            __pycache__/           物質情報工学＿過大.ipynb
# __init__.py               README.md              確認.ipynb

# %%
o_sublattice
# Out:
# ([[4, 4, 0], [0, 8, 0], [0, 0, 3]],
#  [[0.3, 0.0, 0.0],
#   [0.7, 0.0, 0.0],
#   [0.2, 0.3, 0.5],
#   [0.3, 0.5, 0.0],
#   [0.7, 0.5, 0.0],
#   [0.2, 0.8, 0.5],
#   [0.8, 0.2, 0.5],
#   [0.8, 0.7, 0.5]],
#  [16, 16, 16, 16, 16, 16, 16, 16])

# %%
index = 2
name = 'SnOx_index={}'.format(index)
filename = os.path.join('examples', name, "SnOx_index={}_{}.cif".format(index, 42))
write_cif(filename, struct, refine_cell=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-ebac389146c8> in <module>
#       2 name = 'SnOx_index={}'.format(index)
#       3 filename = os.path.join('examples', name, "SnOx_index={}_{}.cif".format(index, 42))
# ----> 4 write_cif(filename, struct, refine_cell=True)
#
# <ipython-input-38-e056a545859e> in write_cif(filename, struct, refine_cell, resize_volume)
#      13     cw = CifWriter(struct)
#      14
# ---> 15     cw.write_file(filename)
#
# ~/.pyenv/versions/miniconda3-4.3.30/envs/graph/lib/python3.7/site-packages/pymatgen/io/cif.py in write_file(self, filename)
#    1368         Write the cif file.
#    1369         """
# -> 1370         with zopen(filename, "wt") as f:
#    1371             f.write(self.__str__())
#    1372
#
# ~/.pyenv/versions/miniconda3-4.3.30/envs/graph/lib/python3.7/site-packages/monty/io.py in zopen(filename, *args, **kwargs)
#      70         return gzip.open(filename, *args, **kwargs)
#      71     else:
# ---> 72         return io.open(filename, *args, **kwargs)
#      73
#      74
#
# FileNotFoundError: [Errno 2] No such file or directory: 'examples/SnOx_index=2/SnOx_index=2_42.cif'
